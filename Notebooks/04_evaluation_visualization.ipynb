# %%
import pandas as pd
import joblib
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# %%
X_test = pd.read_csv("X_test.csv").squeeze()
y_test = pd.read_csv("y_test.csv").squeeze()

model = joblib.load("sentiment_model.pkl")

y_pred = model.predict(X_test)

report_dict = classification_report(y_test, y_pred, zero_division=0, output_dict=True)
report_df = pd.DataFrame(report_dict).transpose()
print(report_df)
# Out:
#                         precision    recall  f1-score     support
#  Acceptance              0.000000  0.000000  0.000000    2.000000
#  Acceptance              0.000000  0.000000  0.000000    0.000000
#  Admiration              0.000000  0.000000  0.000000    1.000000
#  Admiration              0.000000  0.000000  0.000000    1.000000
#  Affection               0.000000  0.000000  0.000000    1.000000
# ...                           ...       ...       ...         ...
#  Whispers of the Past    0.000000  0.000000  0.000000    1.000000
#  Zest                    0.000000  0.000000  0.000000    1.000000
# accuracy                 0.122449  0.122449  0.122449    0.122449
# macro avg                0.013752  0.035147  0.016412  147.000000
# weighted avg             0.023155  0.122449  0.035431  147.000000
#
# [101 rows x 4 columns]

# %%
plt.figure(figsize=(14, 18))

sns.heatmap(
    report_df.iloc[:-1, :-1],
    annot=True,
    fmt=".2f",
    cmap='Blues',
    linewidths=0.5,
    annot_kws={"size": 10} 
)

plt.title("Classification Report Heatmap", fontsize=16)
plt.xticks(fontsize=12, rotation=45)
plt.yticks(fontsize=10, rotation=0)
plt.tight_layout()
plt.show()
